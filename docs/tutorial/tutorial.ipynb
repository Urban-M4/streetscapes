# %% [markdown]
# # Streetscapes workspaces
#
# This notebook provides an example of a workflow using Streetscapes. You can load different data sources and ML models, process streetview images and save generated data to your workspace.
#
# This notebook includes the following steps:
#
# - [Define a workspace](#define-a-workspace)
# - [Obtaining image IDs](#obtaining-images)
# - [Visualise data](#visualise-data)
# - [Download images](#download-images)
# - [Segment images](#segment-images)
# - [Calculate statistics](#calculate-statistics)

# %% [markdown]
# ### Libraries

# %%
import warnings
import ibis
import geopandas as gpd
import contextily
from PIL import Image
from streetscapes.sources import Mapillary
from streetscapes.models import DinoSAM
from streetscapes.streetview import SVWorkspace

warnings.filterwarnings("ignore")
ibis.options.interactive = True

# %% [markdown]
# ### Define a workspace

# %% [markdown]
# Streetscapes has a workspace functionality to facilitate data analysis. Within this workspace, downloaded data, images, segmented masks and analysis for a certain project are self contained and reproducible.
#
# <span style="color:grey;"><i> Note: You can also pass the path to an `.env` file containing configuration options for the workspace. By default, the workspace looks for an `.env` file inside the workspace directory, and if it doesn't exist, it walks the parent tree until it finds one or it reaches the root of the file system. Environment variables are also recognised automatically.</i></span>
#
# First, create a workspace or load an existing one. In this tutorial, we will be doing an analysis of Amsterdam, so we are naming our workspace "Amsterdam":

# %%
ws = SVWorkspace("./Amsterdam")

# %% [markdown]
# If we show the contents of the workspace directory, we can see that a subdirectory for Amsterdam was created as well as a [duckdb](https://duckdb.org/) metadata file.

# %%
ws.show_contents()
# Out:
# Amsterdam/
# ├─metadata.ddb.wal
# ├─metadata.ddb
# └─.gitignore

# %% [markdown]
# Let's now look at where this new workspace is located:

# %%
workspace_path = ws.get_workspace_path()
workspace_path
# Out:
# PosixPath('/Users/clairedonnelly/Documents/Urban-M4/streetscapes/docs/tutorial/Amsterdam')

# %% [markdown]
# ### Obtaining image IDs

# %% [markdown]
# Now let's add which source of images we would like to use. Possible are sources are: [Mapillary](https://www.mapillary.com/), [Kartaview](https://kartaview.org/) and [Amsterdam Open Panorama](https://amsterdam.github.io/projects/open-panorama/). It is also possible to use [Global Streetscapes](https://ual.sg/project/global-streetscapes/) as a data source.
#
# In this example, we will use Mapillary.
#
# <span style="color:red;">NOTE</span>: To use Mapillary, you need to have an API token, which you can obtain from the [Mapillary developer portal](https://www.mapillary.com/developer).
# Store the token in an `.env` file inside your workspace directory as follows:
#
# ```
# MAPILLARY_TOKEN=<your-API-token>
# ```

# %%
mp = Mapillary(ws.env)

# %% [markdown]
# We can then view where these data sources are located. This will be where all images, instances and masks will be stored.

# %%
mp
# Out:
# Mapillary(root_dir='~/Documents/Urban-M4/data/assets/streetscapes/images/mapillary')

# %% [markdown]
# The class provides some convenience attributes and methods. For instance, you can obtain a list of all images that have been downloaded.

# %%
[image.name for image in mp.images]
# Out:
# []

# %%
con = ws.load()

# %% [markdown]
# Let's have a more detailed look into the data sources that we have loaded. We will find the available images based on a bounding box.

# %%
bbox = [4.883466,52.361790,4.916210,52.381494]
metadata = mp.fetch_metadata_bbox(bbox, tile_size=0.1, limit=100, bbox_name="Amsterdam_")
df = mp.convert_to_ibis(metadata)
df.head(5)
# Out:
# /Users/clairedonnelly/Documents/Urban-M4/data/assets/streetscapes/images/mapillary/metadata/Amsterdam_4.88_52.36_4.92_52.38.json already exists, loading records.
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ id               ┃ altitude  ┃ atomic_scale ┃ camera_type     ┃ captured_at   ┃ compass_angle ┃ computed_altitude ┃ computed_compass_angle ┃ computed_geometry                                 ┃ computed_rotation                              ┃ exif_orientation ┃ geometry                                          ┃ height ┃ is_pano ┃ make    ┃ model         ┃ thumb_256_url                                                                    ┃ thumb_1024_url                                                                   ┃ thumb_2048_url                                                                   ┃ thumb_original_url                                                               ┃ sequence               ┃ width ┃ lon      ┃ lat       ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ string           │ float64   │ float64      │ string          │ int64         │ float64       │ float64           │ float64                │ struct<coordinates: array<float64>, type: string> │ array<float64>                                 │ int64            │ struct<coordinates: array<float64>, type: string> │ int64  │ boolean │ string  │ string        │ string                                                                           │ string                                                                           │ string                                                                           │ string                                                                           │ string                 │ int64 │ float64  │ float64   │
# ├──────────────────┼───────────┼──────────────┼─────────────────┼───────────────┼───────────────┼───────────────────┼────────────────────────┼───────────────────────────────────────────────────┼────────────────────────────────────────────────┼──────────────────┼───────────────────────────────────────────────────┼────────┼─────────┼─────────┼───────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼────────────────────────┼───────┼──────────┼───────────┤
# │ 2516466118520607 │ 45.608000 │     1.245082 │ fisheye         │ 1687549484000 │    300.410000 │          1.605634 │             302.037249 │ {'coordinates': [...], 'type': 'Point'}           │ [1.3450108798332, 0.70795736258459, ... +1]    │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro   │ HERO7 Black   │ ]8;id=690654;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfTcIpv5GldmZniVmRu7L9ZSbwqTDto3kjKuPqat2yx9Lw&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ ]8;id=108634;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfRvKAvNsz8ZQwhDYKRi2pUJ3YY-mZs8quazHiTPZG5-cw&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ ]8;id=377043;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfQFwEEMgdQ7NZHi7-rYe4lId0oyQm9YwbKk18bJqdB5yw&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ ]8;id=868842;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfRF9sgkIKVmraxr7KeHLXhCpovqOb6Z8iZm_Hlg9ID95A&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ 3XT8wrxnFU9BcCqKomDvRY │  4000 │ 4.900702 │ 52.367008 │
# │ 5933178466710501 │  3.315950 │     1.010494 │ perspective     │ 1658244064467 │    280.609874 │          2.864860 │             284.736165 │ {'coordinates': [...], 'type': 'Point'}           │ [1.1598292920452, 0.89437935528902, ... +1]    │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3024 │ False   │ Apple   │ iPhone 12 Pro │ ]8;id=510413;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfQolYash-AeVQpfgbBijvTEE7U146zDQIXz_kUD3_sGIw&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ ]8;id=152972;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfTNyxdZNrG21NIsoB1QjKFTbVgmbJhA9KmmGYm59YFgTg&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ ]8;id=233648;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfS4XRXNOa2SrZdlZKyPLw0uxNxpgLYTLZT5l50jDYMMSw&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ ]8;id=832655;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfTFqOT7NNbNfue3jN96T69zuPr2cH1la4GAv4v59igrCA&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ BGfrz7yMAqQ4hx50b9ESOm │  4032 │ 4.915492 │ 52.377229 │
# │ 2867586263507076 │ 47.403808 │     0.984554 │ equirectangular │ 1490260410335 │      0.000000 │          2.029629 │             359.906298 │ {'coordinates': [...], 'type': 'Point'}           │ [1.5812932656715, -0.0027423859709612, ... +1] │                1 │ {'coordinates': [...], 'type': 'Point'}           │   4000 │ True    │ Trimble │ Trimble TMX   │ ]8;id=191641;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?stp=s256x128&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfQyEjTlXuDxBx1agm4HIcWIB5xqhyUKL_O2bH1BkFXFOg&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ ]8;id=753118;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?stp=s1024x512&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfR-dYNtDbIvf-hsNK9_rZxmDn3Rs8RZTp3mLGJfSCj3Uw&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ ]8;id=923868;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?stp=s2048x1024&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfQuKFX7hX5HvxXyefWfObd9LsdBHaySfkPoKA-5eTRzqw&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ ]8;id=677610;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfSr_IFh6WxLKTtdRDGe75mvGmm9-uA6JxL3lPsmrTwU1Q&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ E3NcJ2bz1oK_G7naKkIXrw │  8000 │ 4.914916 │ 52.369498 │
# │ 1457886868300236 │ 37.556000 │     1.244410 │ fisheye         │ 1687549453000 │    280.886000 │          1.778606 │             298.476435 │ {'coordinates': [...], 'type': 'Point'}           │ [1.3194873182936, 0.76321453359038, ... +1]    │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro   │ HERO7 Black   │ ]8;id=233723;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfRbWL4AqP2l-ZRDztiUHVGGrLYXa0WPpkdVa2CWhG3V5g&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ ]8;id=435472;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfS-ZkQprUWLux7yZFiFq0pVp2TTtuZ_XXyaXY5GduhTlA&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ ]8;id=927599;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfQBiMpDXt7UNEXAezxP6J1ElN4O0KsIdpyAFAPtYKxoAg&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ ]8;id=442918;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfSImRDQkYzuksR-vHTxml5-UcuKLCtxOdFGJjGgM04y5A&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ 3XT8wrxnFU9BcCqKomDvRY │  4000 │ 4.901307 │ 52.366799 │
# │ 1597657931128047 │  4.982798 │     1.028072 │ perspective     │ 1729670015613 │    281.075555 │          0.246130 │             290.788977 │ {'coordinates': [...], 'type': 'Point'}           │ [1.2939927407674, 0.90083235897945, ... +1]    │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3024 │ False   │ Apple   │ iPhone 13 Pro │ ]8;id=200659;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfTBB3DjTAFJxvSkLYFdX6lzfC2ExcSzF6nZk-2lWh3JSw&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ ]8;id=491291;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfROZ7ZlEeGsYhssYgENZ5YeCl7freMiA1FEypwi5b8Srw&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ ]8;id=435945;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfSSJn645D8v4mzBqzCNwMkXdWBO7ORKb7214LK_2KdqvQ&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ ]8;id=898990;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfRz4gfbVUoruf2SqnyLHGES_4uv5a46BwXuJh91_qLrdg&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ JwhG8WlEX9of50zHyeF3PL │  4032 │ 4.915610 │ 52.377190 │
# └──────────────────┴───────────┴──────────────┴─────────────────┴───────────────┴───────────────┴───────────────────┴────────────────────────┴───────────────────────────────────────────────────┴────────────────────────────────────────────────┴──────────────────┴───────────────────────────────────────────────────┴────────┴─────────┴─────────┴───────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴────────────────────────┴───────┴──────────┴───────────┘

# %%
t = con.create_table("df1", df, overwrite=True)

# %% [markdown]
# ### Visualise Data

# %% [markdown]
# Now that we have subsetted the data, we might want to see where the images we want to download are located and if we have good coverage of the city.
#
# First, the table needs to be converted to a geopandas dataframe and given an appropriate CRS.

# %%
pdf = df.to_pandas()
gdf = gpd.GeoDataFrame(pdf, geometry=gpd.points_from_xy(pdf.lon, pdf.lat))
gdf.set_crs("EPSG:4326", allow_override=True, inplace=True)
gdf.head(5)
# Out:
#                  id   altitude  atomic_scale      camera_type    captured_at  \
# 0  2516466118520607  45.608000      1.245082          fisheye  1687549484000
# 1  5933178466710501   3.315950      1.010494      perspective  1658244064467
# 2  2867586263507076  47.403808      0.984554  equirectangular  1490260410335
# 3  1457886868300236  37.556000      1.244410          fisheye  1687549453000
# 4  1597657931128047   4.982798      1.028072      perspective  1729670015613
#
#    compass_angle  computed_altitude  computed_compass_angle  \
# 0     300.410000           1.605634              302.037249
# 1     280.609874           2.864860              284.736165
# 2       0.000000           2.029629              359.906298
# 3     280.886000           1.778606              298.476435
# 4     281.075555           0.246130              290.788977
#
#                                    computed_geometry  \
# 0  {'coordinates': [4.9007022911418, 52.367008343...
# 1  {'coordinates': [4.9154919378729, 52.377228962...
# 2  {'coordinates': [4.9149164516868, 52.369498281...
# 3  {'coordinates': [4.9013072567876, 52.366798776...
# 4  {'coordinates': [4.915610197891, 52.3771902170...
#
#                                    computed_rotation  ...     make  \
# 0  [1.3450108798332, 0.70795736258459, -0.8532862...  ...    GoPro
# 1  [1.1598292920452, 0.89437935528902, -1.0881893...  ...    Apple
# 2  [1.5812932656715, -0.0027423859709612, -0.0052...  ...  Trimble
# 3  [1.3194873182936, 0.76321453359038, -0.8889696...  ...    GoPro
# 4  [1.2939927407674, 0.90083235897945, -0.9562557...  ...    Apple
#
#            model                                      thumb_256_url  \
# 0    HERO7 Black  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  iPhone 12 Pro  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 2    Trimble TMX  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 3    HERO7 Black  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  iPhone 13 Pro  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                       thumb_1024_url  \
# 0  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 2  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 3  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                       thumb_2048_url  \
# 0  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 2  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 3  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                   thumb_original_url                sequence  \
# 0  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...  3XT8wrxnFU9BcCqKomDvRY
# 1  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...  BGfrz7yMAqQ4hx50b9ESOm
# 2  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...  E3NcJ2bz1oK_G7naKkIXrw
# 3  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...  3XT8wrxnFU9BcCqKomDvRY
# 4  https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/A...  JwhG8WlEX9of50zHyeF3PL
#
#   width       lon        lat
# 0  4000  4.900702  52.367008
# 1  4032  4.915492  52.377229
# 2  8000  4.914916  52.369498
# 3  4000  4.901307  52.366799
# 4  4032  4.915610  52.377190
#
# [5 rows x 24 columns]

# %% [markdown]
# Then we can plot the image locations:

# %%
ax = gdf.plot(column='uuid', color='red', markersize=3, figsize=(6, 6), alpha=0.5)
contextily.add_basemap(ax, crs=gdf.crs, source=contextily.providers.nlmaps.standaard)

# %% [markdown]
# ### Download images

# %% [markdown]
# Let's first download and visualise a single image:

# %%
image = gdf.iloc[0]
filename = mp.download_image(image.id, image.thumb_1024_url, overwrite=True)
Image.open(filename)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768>

# %% [markdown]
# Now let's do this for the first 50 images of our dataset:

# %%
df_sample = gdf[:50]
image_ids = df_sample.id
urls = df_sample.thumb_1024_url
paths = mp.download_images(image_ids, urls)
# Out:
# Downloading images | mapillary | Done: 100%|██████████| 50/50 [00:00<00:00, 1483.69it/s]

# %% [markdown]
# For examples of other data sources, check out the [documentation section](../examples/use_data_sources.ipynb) related to downloading images.

# %% [markdown]
# ### Segment images
#
# We can load various models and apply them to the image data that we have loaded or generated so far. Currently, Streetscapes supports two segmentation models:
#
# - `MaskFormer`: A relatively small and nimble model that recognises objects from a fixed number of categories.
# - `DinoSAM`: A combination of two independent models that work together to perform instance segmentation simply by providing a prompt. It is much more flexible than `MaskFormer` in that it recognises *arbitrary categories*; however, it is much slower.
#
# In this tutorial we will use `DinoSAM`, for a more in-depth tutorial of segmentation with different models, go [here](../examples/segmentation.ipynb). First, we load the model in a similar manner to data sources. Models are spawned globally and can be reused across multiple workspaces to minimise memory consumption for potentially large models.

# %%
model = DinoSAM()

# %% [markdown]
# We define the categories of objects that we would like to look for in the images that we are segmenting. Categories are defined hierarchically as a nested dictionary. Subcategories (such as `window` and `door` below) will be identified as separate categories, but the pixels that they occupy will be subtracted from ones attributed to their parent (here, `building`). In this way, it is possible to extract building façades excluding windows and doors. Internally, this nested dictionary is flattened, and any overlaps are handled after instances of the corresponding categories have been identified.

# %%
labels = {
    "building": {
        "window": None,
        "door": None,
    },
    "vegetation": None,
    "car": None,
    "truck": None,
    "road": None,
}

# %% [markdown]
# Segment a list of images provided as file paths. Here, we use our subset that we created above. A batch size (defaulting to `10`) can be specified to speed up the segmentation.

# %%
# TODO: Make this function more flexible so columns names can be set
segmentations = model.segment(paths[:5], labels)
# Out:
# Done: 100%|██████████| 1/1 [00:37<00:00, 37.79s/it]

# %% [markdown]
# The masks and the instances are saved as separate files with the same name as the input image but in different formats (NumPy archived arrays and Parquet files, respectively) so that they can be loaded later together. Here, we print the name of the file containing the mask for the first segmented image.

# %%
segmentation = segmentations[0]
segmentation
# Out:
# SVSegmentation(path='~/Documents/Urban-M4/data/assets/streetscapes/images/mapillary/images/segmentations/dinosam/2516466118520607.npz'

# %%
segmentation.get_instance_labels()
# Out:
# {1: 'road',
#  2: 'building',
#  3: 'building',
#  4: 'building',
#  5: 'vegetation',
#  6: 'vegetation',
#  7: 'window',
#  8: 'vegetation',
#  9: 'vegetation',
#  10: 'door',
#  11: 'vegetation',
#  12: 'vegetation',
#  13: 'vegetation',
#  14: 'vegetation',
#  15: 'window',
#  16: 'road',
#  17: 'door'}

# %% [markdown]
# Show the distinct categories (out of the ones that we requested) identified by this model.

# %%
segmentation.get_instance_labels(as_table=True).select('label').distinct()
# Out:
# ┏━━━━━━━━━━━━┓
# ┃ label      ┃
# ┡━━━━━━━━━━━━┩
# │ string     │
# ├────────────┤
# │ vegetation │
# │ window     │
# │ road       │
# │ building   │
# │ door       │
# └────────────┘

# %% [markdown]
# Visualise the parts of the image corresponding to some object categories of interest (here, we ask for everything that is labelled as a `building`).

# %%
masks = segmentation.get_masks()

# %%
segmentation.visualise(['building', "window"])
# Out:
# (<Figure size 1600x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# If the `visualise()` method is called without an argument, all the identified categories are visualised.

# %%
segmentation.visualise()
# Out:
# (<Figure size 1600x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# We can also extract instances for individual categories and and visualise them in isolation.

# %%
buildings = segmentation.get_instances("building", exclude=["window", "door"])

# %% [markdown]
# We will extract the first `building` instance to make working with the instance a bit easier. Here, we also visualise the instance using the built-in `visualise()` method to show the instance in isolation, with the remainder of the image blanked out.

# %%
building = buildings[1]
building.visualise()
# Out:
# (<Figure size 1600x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# We can also visualise a specific channel of the image. Here, we visualise the red channel, which corresponds to index `0`.

# %%
building.visualise(channel=0)
# Out:
# (<Figure size 1600x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# We can also extract a NumPy array representing the pixel values that correspond to the instance by using the built-in `masked()` method. This method also allows us to extract a specific channel. The result can then be used to compute statistics, such as `mean()`.

# %%
masked = building.masked()
masked_red = building.masked(channel=0)

# %% [markdown]
# For instance, we can easily compute the 'mean colour' of the instance...

# %%
masked_mean = masked.mean(axis = 0)
masked_mean
# Out:
# array([59.58839167, 60.71634914, 59.60008861])

# %% [markdown]
# ...or the mean for a specific channel:

# %%
masked_red_mean = masked_red.mean(axis=0)
masked_red_mean
# Out:
# np.float64(59.58839167035888)

# %% [markdown]
# We can also perform the same operation on an HSV version of the image by passing `hsv=True` to the `masked()` method:

# %%
masked_hsv = building.masked(hsv=True)
masked_hsv
# Out:
# array([[0.5787037 , 0.20224719, 0.69803922],
#        [0.58571429, 0.23333333, 0.58823529],
#        [0.58571429, 0.30701754, 0.44705882],
#        ...,
#        [0.125     , 0.5       , 0.09411765],
#        [0.125     , 0.8       , 0.05882353],
#        [0.14285714, 0.7       , 0.07843137]], shape=(11285, 3))

# %%
masked_v = building.masked(hsv=True, channel=2)
masked_v
# Out:
# array([0.69803922, 0.58823529, 0.44705882, ..., 0.09411765, 0.05882353,
#        0.07843137], shape=(11285,))

# %% [markdown]
# A built-in method is provided for convenience to extract the value (brightness) of the instance. It performs the same computation as the cell above.

# %%
brightness = building.brightness()
brightness.mean()
# Out:
# np.float64(0.25150442631638387)

# %% [markdown]
# ### Calculate statistics

# %% [markdown]
# We can now compute some statistics on the instances that we have extracted. Here we will calculate the mean brightness of buildings as a proxy for albedo.

# %%
# Compute albedo (mean V from HSV)
building_means = {}
for seg in segmentations:
    # Make sure instances contain a building
    buildings = seg.get_instances("building", exclude=["window", "door"])
    if not buildings:
        print("No buildings found")
    else:
        # Take mean and add to dictionary with image name
        buildings = seg.get_instances("building", exclude=["window", "door"], merge = True)
        building_means[seg.image_path.stem] = buildings.brightness().mean()

# %% [markdown]
# Once we have our dictionary of values, these can be turned back into a table and joined with the sample dataframe. This gives up a table with all of the metadata available for the image plus our calculated brightness.

# %%
# Convert sample dataframe to a table
sample = ibis.memtable(df_sample)

# Convert dictionary to a table
table = {
    "id": list(building_means.keys()),
    "brightness": list(building_means.values())
}
brightness = ibis.memtable(table)

# Join tables together on "id" to get metadata
merge = brightness.join(sample, "id", how="left")
merge
# Out:
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ id               ┃ brightness ┃ id_right         ┃ altitude  ┃ atomic_scale ┃ camera_type     ┃ captured_at   ┃ compass_angle ┃ computed_altitude ┃ computed_compass_angle ┃ computed_geometry                                 ┃ computed_rotation                              ┃ exif_orientation ┃ geometry                                                            ┃ height ┃ is_pano ┃ make    ┃ model         ┃ thumb_256_url                                                                    ┃ thumb_1024_url                                                                   ┃ thumb_2048_url                                                                   ┃ thumb_original_url                                                               ┃ sequence               ┃ width ┃ lon      ┃ lat       ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ string           │ float64    │ string           │ float64   │ float64      │ string          │ int64         │ float64       │ float64           │ float64                │ struct<coordinates: array<float64>, type: string> │ array<float64>                                 │ int64            │ binary                                                              │ int64  │ boolean │ string  │ string        │ string                                                                           │ string                                                                           │ string                                                                           │ string                                                                           │ string                 │ int64 │ float64  │ float64   │
# ├──────────────────┼────────────┼──────────────────┼───────────┼──────────────┼─────────────────┼───────────────┼───────────────┼───────────────────┼────────────────────────┼───────────────────────────────────────────────────┼────────────────────────────────────────────────┼──────────────────┼─────────────────────────────────────────────────────────────────────┼────────┼─────────┼─────────┼───────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼────────────────────────┼───────┼──────────┼───────────┤
# │ 2516466118520607 │   0.417608 │ 2516466118520607 │ 45.608000 │     1.245082 │ fisheye         │ 1687549484000 │    300.410000 │          1.605634 │             302.037249 │ {'coordinates': [...], 'type': 'Point'}           │ [1.3450108798332, 0.70795736258459, ... +1]    │                1 │ b'\x01\x01\x00\x00\x00\x93\x8b\x8f\xb3Q\x9a\x13@\xd48!!\xfa.J@'     │   3000 │ False   │ GoPro   │ HERO7 Black   │ ]8;id=636652;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfTcIpv5GldmZniVmRu7L9ZSbwqTDto3kjKuPqat2yx9Lw&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ ]8;id=778810;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfRvKAvNsz8ZQwhDYKRi2pUJ3YY-mZs8quazHiTPZG5-cw&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ ]8;id=161422;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfQFwEEMgdQ7NZHi7-rYe4lId0oyQm9YwbKk18bJqdB5yw&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ ]8;id=512135;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJrjj5_WcgpggDSbFKhIWIA6a64bZKlWiVFsBglgM7uOnuXZHXkYYbvGNiGux1vWR3vUYEPST6CHaA3UsvBhh_TByUsju155X3f6mCOGl6o8iBz9jQLVGg?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkAyC2ptuCSWkvJ2Q4gk8W9fD6BPya0afrj8en1TAUEQVdwlMUwP18AxR4yYj9xxFwT2Szfl37ZZatWK0LZ3-r5&ccb=10-5&oh=00_AfRF9sgkIKVmraxr7KeHLXhCpovqOb6Z8iZm_Hlg9ID95A&oe=68B04FC4&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-HdVb0xRtgt6zxSj5n82aJA-RpNw89DJ…]8;;\ │ 3XT8wrxnFU9BcCqKomDvRY │  4000 │ 4.900702 │ 52.367008 │
# │ 5933178466710501 │   0.280801 │ 5933178466710501 │  3.315950 │     1.010494 │ perspective     │ 1658244064467 │    280.609874 │          2.864860 │             284.736165 │ {'coordinates': [...], 'type': 'Point'}           │ [1.1598292920452, 0.89437935528902, ... +1]    │                1 │ b'\x01\x01\x00\x00\x00\xbf\xa9\xf3\xb7v\xa9\x13@\xd7\xbc\xe4\tI0J@' │   3024 │ False   │ Apple   │ iPhone 12 Pro │ ]8;id=119266;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfQolYash-AeVQpfgbBijvTEE7U146zDQIXz_kUD3_sGIw&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ ]8;id=231475;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfTNyxdZNrG21NIsoB1QjKFTbVgmbJhA9KmmGYm59YFgTg&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ ]8;id=362366;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfS4XRXNOa2SrZdlZKyPLw0uxNxpgLYTLZT5l50jDYMMSw&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ ]8;id=299226;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7txy5STnRftg4-lsnQ0warmGJiPK23rCQtAEFsPzoNNx3gB67DZwLmbo8f36qEZbW0cShPsrfwr__no7qv9F2vRseYRwOwAfXCjw9Zv7kbJdydGXCNCUI0?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkETDRlCTHwcd0dN2HzWi0NGr1niBBa-iX9xxDVggyZz-IiGevlH1GuUAc-s_I4n0DrCqLmUbrlICObyqpzxU3F&ccb=10-5&oh=00_AfTFqOT7NNbNfue3jN96T69zuPr2cH1la4GAv4v59igrCA&oe=68B02A0D&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An_YqkOq9MYrIB6kHRM2RCWc9PQvn0J1R7…]8;;\ │ BGfrz7yMAqQ4hx50b9ESOm │  4032 │ 4.915492 │ 52.377229 │
# │ 2867586263507076 │   0.465307 │ 2867586263507076 │ 47.403808 │     0.984554 │ equirectangular │ 1490260410335 │      0.000000 │          2.029629 │             359.906298 │ {'coordinates': [...], 'type': 'Point'}           │ [1.5812932656715, -0.0027423859709612, ... +1] │                1 │ b'\x01\x01\x00\x00\x00\xc8D\xba\xdb\xdf\xa8\x13@\x7f\xf8=\xb8K/J@'  │   4000 │ True    │ Trimble │ Trimble TMX   │ ]8;id=12361;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?stp=s256x128&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfQyEjTlXuDxBx1agm4HIcWIB5xqhyUKL_O2bH1BkFXFOg&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ ]8;id=739115;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?stp=s1024x512&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfR-dYNtDbIvf-hsNK9_rZxmDn3Rs8RZTp3mLGJfSCj3Uw&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ ]8;id=755408;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?stp=s2048x1024&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfQuKFX7hX5HvxXyefWfObd9LsdBHaySfkPoKA-5eTRzqw&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ ]8;id=780585;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWPO9hy8IAHK4cFF2bhbEjp83zWyuLFoE3r7A1JihSWgYtEkfEo8IrpO1rqgTVj9KcdSUuM5wEAOckDFVzt-WOGEmyvMVY_LgXFg-lUwUj5ZajXFT_icGq_g?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkG22SETFmlMCGJCqb_Hyb-Os0V29tNx7WYopyBISMXeE3JDMYQJ0ggvKGALh2u524fUOUv32YHDHWfttWQbtWA&ccb=10-5&oh=00_AfSr_IFh6WxLKTtdRDGe75mvGmm9-uA6JxL3lPsmrTwU1Q&oe=68B03FCF&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An-zehhks3xYkwerp49_k6CjpuvUs8CyWP…]8;;\ │ E3NcJ2bz1oK_G7naKkIXrw │  8000 │ 4.914916 │ 52.369498 │
# │ 1457886868300236 │   0.407052 │ 1457886868300236 │ 37.556000 │     1.244410 │ fisheye         │ 1687549453000 │    280.886000 │          1.778606 │             298.476435 │ {'coordinates': [...], 'type': 'Point'}           │ [1.3194873182936, 0.76321453359038, ... +1]    │                1 │ b'\x01\x01\x00\x00\x00l3\x1eJ\xf0\x9a\x13@\x08\xa0&C\xf3.J@'        │   3000 │ False   │ GoPro   │ HERO7 Black   │ ]8;id=630397;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfRbWL4AqP2l-ZRDztiUHVGGrLYXa0WPpkdVa2CWhG3V5g&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ ]8;id=810167;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfS-ZkQprUWLux7yZFiFq0pVp2TTtuZ_XXyaXY5GduhTlA&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ ]8;id=278451;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfQBiMpDXt7UNEXAezxP6J1ElN4O0KsIdpyAFAPtYKxoAg&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ ]8;id=560355;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXmLixQXMeefiTfrcEE0RVLgdy4Y9RZg4hBD9pM2Hc24onh1-0V4kfLVtbWJDVLvEVloRSyEhD_74mC5_K2P5DL74521QCncQWWGmHDWTPmEoElClgb7imBk?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdmVAcWMujOckwTDxbf3Mzk2KNsNj3omF7DI5NbP97nqrXgOvPn-uLarrh_P_j6vQ_J36fJkmbjEHFOJuQEb6vTx&ccb=10-5&oh=00_AfSImRDQkYzuksR-vHTxml5-UcuKLCtxOdFGJjGgM04y5A&oe=68B023CB&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9GQ7BjiQ2Ez41a9-SZtDjoEFu6ayjlXm…]8;;\ │ 3XT8wrxnFU9BcCqKomDvRY │  4000 │ 4.901307 │ 52.366799 │
# │ 1597657931128047 │   0.639307 │ 1597657931128047 │  4.982798 │     1.028072 │ perspective     │ 1729670015613 │    281.075555 │          0.246130 │             290.788977 │ {'coordinates': [...], 'type': 'Point'}           │ [1.2939927407674, 0.90083235897945, ... +1]    │                1 │ b'\x01\x01\x00\x00\x00\xc1M?\xb8\x95\xa9\x13@R;\xdf\xc4G0J@'        │   3024 │ False   │ Apple   │ iPhone 13 Pro │ ]8;id=283818;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfTBB3DjTAFJxvSkLYFdX6lzfC2ExcSzF6nZk-2lWh3JSw&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ ]8;id=17366;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfROZ7ZlEeGsYhssYgENZ5YeCl7freMiA1FEypwi5b8Srw&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ ]8;id=933256;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfSSJn645D8v4mzBqzCNwMkXdWBO7ORKb7214LK_2KdqvQ&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ ]8;id=104255;https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXxZ40pSRuEwFTyOEbgCHHJ4hyNVaXyG7PtDMmBu0r8BZ66GrSg6gAIPCdObHwZX084HI4gTSon-6qvxz4fut_T3s9_9mvOfmmHK24ZOkWIewjARqaJUL_Gs?edm=AOnQwmMEAAAA&_nc_gid=8-7LsM5sgtJehnaTUMprjQ&_nc_oc=AdkHYzJiCxHhSoo-Li0fC_jgT7-pxbDzryz9MemAQhaBUy7LXPP21MaHTYDEmB-G5q1XHJjTnG8au1jX3i7v9eC7&ccb=10-5&oh=00_AfRz4gfbVUoruf2SqnyLHGES_4uv5a46BwXuJh91_qLrdg&oe=68B01FDD&_nc_sid=201bca\https://scontent-muc2-1.xx.fbcdn.net/m1/v/t6/An9zRPknAQrJfCNsJaSTlfi_91jHgEBVXx…]8;;\ │ JwhG8WlEX9of50zHyeF3PL │  4032 │ 4.915610 │ 52.377190 │
# └──────────────────┴────────────┴──────────────────┴───────────┴──────────────┴─────────────────┴───────────────┴───────────────┴───────────────────┴────────────────────────┴───────────────────────────────────────────────────┴────────────────────────────────────────────────┴──────────────────┴─────────────────────────────────────────────────────────────────────┴────────┴─────────┴─────────┴───────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴────────────────────────┴───────┴──────────┴───────────┘

# %% [markdown]
# This means that we can now plot the building brightness on a map:

# %%
merge_df = merge.to_pandas()
gdf_merge = gpd.GeoDataFrame(merge_df, geometry=gpd.points_from_xy(merge_df.lon, merge_df.lat), crs="EPSG:4326")
ax = gdf_merge.plot(column='brightness', cmap='Reds', legend=True, markersize=10, figsize=(6, 6), alpha=0.7)
contextily.add_basemap(ax, crs=gdf_merge.crs, source=contextily.providers.nlmaps.standaard)

# %%
# TODO:
# instance.get_material()

# TODO:
# Add statistics to metadata

# TODO:
# Add model parameters to the segmentation metadata for each image (parquet file)
