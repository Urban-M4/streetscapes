# %% [markdown]
# # Streetscapes workspaces
#
# This notebook provides an example of a workflow using Streetscapes. You can load different data sources and ML models, process streetview images and save generated data to your workspace.
#
# This notebook includes the following steps:
#
# - [Define a workspace](#define-a-workspace)
# - [Obtaining images](#obtaining-images)
# - [Subset data](#2---subset-data)
# - [Visualise data](#3---visualise-data)
# - [Download images](#4---download-images)
# - [Segment images](#5---segment-images)
# - [Calculate statistics](#6---calculate-statistics)

# %% [markdown]
# ### Libraries

# %%
# --------------------------------------
import warnings

warnings.filterwarnings("ignore")

# --------------------------------------
import ibis

ibis.options.interactive = True

# --------------------------------------
import geopandas as gpd

# --------------------------------------
import contextily

# --------------------------------------
from PIL import Image

# --------------------------------------
from streetscapes.sources import Mapillary
from streetscapes.models import DinoSAM
from streetscapes.streetview import SVWorkspace

# %% [markdown]
# ### Define a workspace

# %% [markdown]
# Streetscapes has a workspace functionality to facilitate data analysis. Within this workspace, downloaded data, images, segmented masks and analysis for a certain project are self contained and reproducible.
#
# <span style="color:grey;"><i> Note: You can also pass the path to an `.env` file containing configuration options for the workspace. By default, the workspace looks for an `.env` file inside the workspace directory, and if it doesn't exist, it walks the parent tree until it finds one or it reaches the root of the file system. Environment variables are also recognised automatically.</i></span>
#
# First, create a workspace or load an existing one. In this tutorial, we will be doing an analysis of Amsterdam, so we are naming our workspace "Amsterdam":

# %%
ws = SVWorkspace("./Amsterdam")

# %% [markdown]
# If we show the contents of the workspace directory, we can see that a subdirectory for Amsterdam was created as well as a [duckdb](https://duckdb.org/) metadata file.

# %%
ws.show_contents()
# Out:
# Amsterdam/
# ├─.gitignore
# ├─.env
# └─metadata.db

# %% [markdown]
# Let's now look at where this new workspace is located:

# %%
workspace_path = ws.get_workspace_path()
workspace_path
# Out:
# PosixPath('/home/hobbes/code/github/streetscapes/remote/docs/tutorial/Amsterdam')

# %% [markdown]
# ### Obtaining images

# %% [markdown]
# Now let's add which source of images we would like to use. Possible are sources are: [Mapillary](https://www.mapillary.com/), [Kartaview](https://kartaview.org/) and [Amsterdam Open Panorama](https://amsterdam.github.io/projects/open-panorama/). It is also possible to use [Global Streetscapes](https://ual.sg/project/global-streetscapes/) as a data source.
#
# In this example, we will use Mapillary.
#
# <span style="color:red;">NOTE</span>: To use Mapillary, you need to have an API token, which you can obtain from the [Mapillary developer portal](https://www.mapillary.com/developer).
# Store the token in an `.env` file inside your workspace directory as follows:
#
# ```
# MAPILLARY_TOKEN=<your-API-token>
# ```

# %%
mp = Mapillary(ws.env)

# %% [markdown]
# We can then view where these data sources are located. This will be where all images, instances and masks will be stored.

# %%
mp
# Out:
# Mapillary(root_dir='~/.cache/huggingface/assets/streetscapes/images/mapillary')

# %% [markdown]
# Let's have a more detailed look into the data sources that we have loaded. We will find the available images based on a bounding box.

# %%
bbox = [4.883466,52.361790,4.916210,52.381494]
df = mp.fetch_image_ids(bbox=bbox)
hdf = df.head(5)
hdf
# Out:
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ id               ┃ altitude  ┃ atomic_scale ┃ camera_type ┃ captured_at   ┃ compass_angle ┃ computed_altitude ┃ computed_compass_angle ┃ computed_geometry                                 ┃ computed_rotation                            ┃ exif_orientation ┃ geometry                                          ┃ height ┃ is_pano ┃ make   ┃ model         ┃ thumb_256_url                                                                    ┃ thumb_1024_url                                                                   ┃ thumb_2048_url                                                                   ┃ thumb_original_url                                                               ┃ sequence               ┃ width ┃ lon      ┃ lat       ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ string           │ float64   │ float64      │ string      │ int64         │ float64       │ float64           │ float64                │ struct<coordinates: array<float64>, type: string> │ array<float64>                               │ int64            │ struct<coordinates: array<float64>, type: string> │ int64  │ boolean │ string │ string        │ string                                                                           │ string                                                                           │ string                                                                           │ string                                                                           │ string                 │ int64 │ float64  │ float64   │
# ├──────────────────┼───────────┼──────────────┼─────────────┼───────────────┼───────────────┼───────────────────┼────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┼───────────────────────────────────────────────────┼────────┼─────────┼────────┼───────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼────────────────────────┼───────┼──────────┼───────────┤
# │ 2172293386289344 │ 50.098000 │     0.802639 │ fisheye     │ 1683741159000 │    348.078913 │          2.665259 │             345.561079 │ {'coordinates': [...], 'type': 'Point'}           │ [1.5538203792879, 0.22772272942943, ... +1]  │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro  │ HERO7 Black   │ ]8;id=545891;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0Il8xo38sMprvJoixtXizNQ4_bYiQrc_qLWVX-nfjOhIYbch8WLEL_5CCYE8ypf0dSvITv5_nOOnSLKVsdv1HU_WiqcrTnbItuJTJBis2AKrefQwo8f_58?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkXiYW_IWoLXHn6RYmoE6fC0CGwCHKfWHaFUzM7iG62Zd7CG4ALFdEcdN64ciGKvjI&ccb=10-5&oh=00_AfIdh3WCo8C8qqj8K_3KO_756erylCVE-DRsxXIDptovmQ&oe=68441608&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0…]8;;\ │ ]8;id=111514;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0Il8xo38sMprvJoixtXizNQ4_bYiQrc_qLWVX-nfjOhIYbch8WLEL_5CCYE8ypf0dSvITv5_nOOnSLKVsdv1HU_WiqcrTnbItuJTJBis2AKrefQwo8f_58?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkXiYW_IWoLXHn6RYmoE6fC0CGwCHKfWHaFUzM7iG62Zd7CG4ALFdEcdN64ciGKvjI&ccb=10-5&oh=00_AfK9CH-StSr4p8jUCVd_1W6Nf7UF48kEJaBoQvFoce_TWA&oe=68441608&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0…]8;;\ │ ]8;id=659786;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0Il8xo38sMprvJoixtXizNQ4_bYiQrc_qLWVX-nfjOhIYbch8WLEL_5CCYE8ypf0dSvITv5_nOOnSLKVsdv1HU_WiqcrTnbItuJTJBis2AKrefQwo8f_58?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkXiYW_IWoLXHn6RYmoE6fC0CGwCHKfWHaFUzM7iG62Zd7CG4ALFdEcdN64ciGKvjI&ccb=10-5&oh=00_AfI2uSdAg0kTURWb3G1e_49THymMdFeg-lXRVEOQ_zjf1w&oe=68441608&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0…]8;;\ │ ]8;id=5624;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0Il8xo38sMprvJoixtXizNQ4_bYiQrc_qLWVX-nfjOhIYbch8WLEL_5CCYE8ypf0dSvITv5_nOOnSLKVsdv1HU_WiqcrTnbItuJTJBis2AKrefQwo8f_58?edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkXiYW_IWoLXHn6RYmoE6fC0CGwCHKfWHaFUzM7iG62Zd7CG4ALFdEcdN64ciGKvjI&ccb=10-5&oh=00_AfJRG3YelrFs1Ncv7d5GOTmOJm780ZDAroC_3KKBice46A&oe=68441608&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-yfbmbSEQsooYLDUos3-w4M6oQxa1lJ0…]8;;\ │ hgz5csEuyw4HqBGUC1XZQl │  4000 │ 4.895805 │ 52.371905 │
# │ 2214473772041985 │  2.113821 │   243.100007 │ perspective │ 1651584681027 │      4.766724 │          1.999902 │              15.067546 │ {'coordinates': [...], 'type': 'Point'}           │ [1.5653501585152, -0.17028310687785, ... +1] │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3024 │ False   │ Apple  │ iPhone 13 Pro │ ]8;id=701428;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1MtqjsmynlycBZEDExVRd_Sa2-VLh8x0j2ZAt6vF9SAh6KOumN6dZ_G8By6PKUZtg_AFuDOJfOjFm0MIS111hgo2PX58hfRzwpKhGosIZgf5ZprgolgUeMPDyg?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=Adkgqu97so-1nvHYgXHbwRmQEd32doO9GI92vs6X5rs_G6AG44GkG2OR_lCGMlwUo6E&ccb=10-5&oh=00_AfIxxg1SK2uhkdTLiRh6xbciq2pZu_EDrzOvsdbqbelTFw&oe=684410F2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1Mtqjs…]8;;\ │ ]8;id=974550;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1MtqjsmynlycBZEDExVRd_Sa2-VLh8x0j2ZAt6vF9SAh6KOumN6dZ_G8By6PKUZtg_AFuDOJfOjFm0MIS111hgo2PX58hfRzwpKhGosIZgf5ZprgolgUeMPDyg?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=Adkgqu97so-1nvHYgXHbwRmQEd32doO9GI92vs6X5rs_G6AG44GkG2OR_lCGMlwUo6E&ccb=10-5&oh=00_AfKkej3yKD4CNJYafa0Ct9NYNUeXVtWDTDmdPGKF5buF3A&oe=684410F2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1Mtqjs…]8;;\ │ ]8;id=852626;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1MtqjsmynlycBZEDExVRd_Sa2-VLh8x0j2ZAt6vF9SAh6KOumN6dZ_G8By6PKUZtg_AFuDOJfOjFm0MIS111hgo2PX58hfRzwpKhGosIZgf5ZprgolgUeMPDyg?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=Adkgqu97so-1nvHYgXHbwRmQEd32doO9GI92vs6X5rs_G6AG44GkG2OR_lCGMlwUo6E&ccb=10-5&oh=00_AfKr0M1WuF0HZD6djV6nfuakCaH89C0WjtjtC08nroabiA&oe=684410F2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1Mtqjs…]8;;\ │ ]8;id=358894;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1MtqjsmynlycBZEDExVRd_Sa2-VLh8x0j2ZAt6vF9SAh6KOumN6dZ_G8By6PKUZtg_AFuDOJfOjFm0MIS111hgo2PX58hfRzwpKhGosIZgf5ZprgolgUeMPDyg?edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=Adkgqu97so-1nvHYgXHbwRmQEd32doO9GI92vs6X5rs_G6AG44GkG2OR_lCGMlwUo6E&ccb=10-5&oh=00_AfKnc7RcEs9GcsM76LhDOZRWcz7Gicjo8VobmSfIvDsz9w&oe=684410F2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An975v1AyVBsw3PNb8J2FBTdTqaN1Mtqjs…]8;;\ │ EXfdPov1FJBupzq02U9IeV │  4032 │ 4.890289 │ 52.365339 │
# │ 2201783443340884 │ 51.612000 │     1.035112 │ fisheye     │ 1687547597000 │    355.487000 │          1.194646 │             343.071082 │ {'coordinates': [...], 'type': 'Point'}           │ [1.5102157453911, 0.26171299179499, ... +1]  │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro  │ HERO7 Black   │ ]8;id=97652;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptXcRzsRkPaT30Xn4bjVSipMkN0newNzDTgIgHwAGMUjGE0rbZZHrBiS7Kt-ukoe2AzWpem4mlAN1EQH3ejYrTbQr_LE8MMN7PepyfbMFa4XOlGPOqFmT1VQ?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkkN2ptfSowO85nHetr_wxtsKZAtPjg5KqqTqH8rIHsC8LDGd92KuuRRwozivvyFB0&ccb=10-5&oh=00_AfKDlWaAMbbMPAy_X1du3sTLUraQllkelQlsZQED6tshuQ&oe=68441EC7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptX…]8;;\ │ ]8;id=234275;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptXcRzsRkPaT30Xn4bjVSipMkN0newNzDTgIgHwAGMUjGE0rbZZHrBiS7Kt-ukoe2AzWpem4mlAN1EQH3ejYrTbQr_LE8MMN7PepyfbMFa4XOlGPOqFmT1VQ?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkkN2ptfSowO85nHetr_wxtsKZAtPjg5KqqTqH8rIHsC8LDGd92KuuRRwozivvyFB0&ccb=10-5&oh=00_AfLJBm8hrt61dLZKJVDdQBJp7JTRE6cVKTdsivcnrPq8Kw&oe=68441EC7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptX…]8;;\ │ ]8;id=136687;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptXcRzsRkPaT30Xn4bjVSipMkN0newNzDTgIgHwAGMUjGE0rbZZHrBiS7Kt-ukoe2AzWpem4mlAN1EQH3ejYrTbQr_LE8MMN7PepyfbMFa4XOlGPOqFmT1VQ?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkkN2ptfSowO85nHetr_wxtsKZAtPjg5KqqTqH8rIHsC8LDGd92KuuRRwozivvyFB0&ccb=10-5&oh=00_AfJlwcrInIbHu3P7mUVNY64FNYrRQLI-aS8EBYQhw8Ou8A&oe=68441EC7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptX…]8;;\ │ ]8;id=883202;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptXcRzsRkPaT30Xn4bjVSipMkN0newNzDTgIgHwAGMUjGE0rbZZHrBiS7Kt-ukoe2AzWpem4mlAN1EQH3ejYrTbQr_LE8MMN7PepyfbMFa4XOlGPOqFmT1VQ?edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdkkN2ptfSowO85nHetr_wxtsKZAtPjg5KqqTqH8rIHsC8LDGd92KuuRRwozivvyFB0&ccb=10-5&oh=00_AfIrWaJOuC5xXoXfSZrKzJTmn2syiediNC9vfRWB2n1duQ&oe=68441EC7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_vlQIGOW3Z2mD-3ZNE6kjuxmpqHieptX…]8;;\ │ fz4WBbMQTVZ1Gqoe7PdKjX │  4000 │ 4.910891 │ 52.364557 │
# │ 2199564663716780 │ 49.451000 │     0.997227 │ fisheye     │ 1717398810000 │     39.041000 │          2.504714 │              48.565448 │ {'coordinates': [...], 'type': 'Point'}           │ [1.3031780175287, -0.70662946877827, ... +1] │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro  │ HERO7 Black   │ ]8;id=395156;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgXHflBZ3YfLsKhhuyJhQHSFFuoG2t7np2vYUytUuZOWgJzu3O9yMANVwNFWX44oknDxxAElrVCM-394VjJ61g4eGYuH2blf4rNlYP6W4eFeXxxlFjPfOPw?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdnHfzZYOo1Tuix2T7RocpEeMyIHeAtdyQQDazTtelCR7n6iYbvlb-kfpV-KPXbzXLM&ccb=10-5&oh=00_AfIE4BwTbBJq2_OvIkG0f1GO3grRynW-YKDRDcS5oG8MAg&oe=68440DD2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgX…]8;;\ │ ]8;id=372296;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgXHflBZ3YfLsKhhuyJhQHSFFuoG2t7np2vYUytUuZOWgJzu3O9yMANVwNFWX44oknDxxAElrVCM-394VjJ61g4eGYuH2blf4rNlYP6W4eFeXxxlFjPfOPw?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdnHfzZYOo1Tuix2T7RocpEeMyIHeAtdyQQDazTtelCR7n6iYbvlb-kfpV-KPXbzXLM&ccb=10-5&oh=00_AfKMzbcCwbZkYR1IWLtAY2a-NAkJWzRYK0Ku2FiQ7OLVRQ&oe=68440DD2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgX…]8;;\ │ ]8;id=117549;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgXHflBZ3YfLsKhhuyJhQHSFFuoG2t7np2vYUytUuZOWgJzu3O9yMANVwNFWX44oknDxxAElrVCM-394VjJ61g4eGYuH2blf4rNlYP6W4eFeXxxlFjPfOPw?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdnHfzZYOo1Tuix2T7RocpEeMyIHeAtdyQQDazTtelCR7n6iYbvlb-kfpV-KPXbzXLM&ccb=10-5&oh=00_AfKlp3ruSkCnL3p8BRyEn5mANjblH8zQ9BbN5nWG_qSc1g&oe=68440DD2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgX…]8;;\ │ ]8;id=447596;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgXHflBZ3YfLsKhhuyJhQHSFFuoG2t7np2vYUytUuZOWgJzu3O9yMANVwNFWX44oknDxxAElrVCM-394VjJ61g4eGYuH2blf4rNlYP6W4eFeXxxlFjPfOPw?edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdnHfzZYOo1Tuix2T7RocpEeMyIHeAtdyQQDazTtelCR7n6iYbvlb-kfpV-KPXbzXLM&ccb=10-5&oh=00_AfJFFDkBl9TVCrDYrJb-ktAikcVwJ8HE3PPfz8Kk9qui6A&oe=68440DD2&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An-2bQswOkDIa-_U37jFrmCb9gowrMpMgX…]8;;\ │ WHX0bGlqYRSDUtZF13wdON │  4000 │ 4.888970 │ 52.368444 │
# │ 3269640993308803 │ 70.100000 │     0.449626 │ perspective │ 1657637093000 │    132.172247 │          0.114532 │             132.466114 │ {'coordinates': [...], 'type': 'Point'}           │ [0.93192892253876, -2.0494630200259, ... +1] │                1 │ {'coordinates': [...], 'type': 'Point'}           │    960 │ False   │ Tesla  │ none          │ ]8;id=639522;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNzo63ws2JJkkna2KaJkvcMPb7VJo2t-N4sW2Ihv12a5YziDZGxhsR-ac4DKYbPX4c0y_K8J3jFkoBvWpLDInia76fjzmHKd6zImK-w1DRLDbZb5gO61HTQ?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdlK74zWnBFLBc2BIbCT_wSFpLpl_6Oj0ikHBNGG5q-7XykgulkP7GVUCCGnyOJ7MP0&ccb=10-5&oh=00_AfL-RCwobNgpf_AvqlHwF_ntKGGwnMkstJ76-LfNAy6tTw&oe=6844309C&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNz…]8;;\ │ ]8;id=937750;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNzo63ws2JJkkna2KaJkvcMPb7VJo2t-N4sW2Ihv12a5YziDZGxhsR-ac4DKYbPX4c0y_K8J3jFkoBvWpLDInia76fjzmHKd6zImK-w1DRLDbZb5gO61HTQ?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdlK74zWnBFLBc2BIbCT_wSFpLpl_6Oj0ikHBNGG5q-7XykgulkP7GVUCCGnyOJ7MP0&ccb=10-5&oh=00_AfKSkyeexC4vq4SoZ8UZD2rZdA-l3z6r1Ao4ABgbcrTZwQ&oe=6844309C&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNz…]8;;\ │ ]8;id=106053;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNzo63ws2JJkkna2KaJkvcMPb7VJo2t-N4sW2Ihv12a5YziDZGxhsR-ac4DKYbPX4c0y_K8J3jFkoBvWpLDInia76fjzmHKd6zImK-w1DRLDbZb5gO61HTQ?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdlK74zWnBFLBc2BIbCT_wSFpLpl_6Oj0ikHBNGG5q-7XykgulkP7GVUCCGnyOJ7MP0&ccb=10-5&oh=00_AfLJHLF0VSBTB-NXQiMD-eariLHUtpaj242DfIstYVXXJQ&oe=6844309C&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNz…]8;;\ │ ]8;id=343594;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNzo63ws2JJkkna2KaJkvcMPb7VJo2t-N4sW2Ihv12a5YziDZGxhsR-ac4DKYbPX4c0y_K8J3jFkoBvWpLDInia76fjzmHKd6zImK-w1DRLDbZb5gO61HTQ?edm=AOnQwmMEAAAA&_nc_gid=_Gi0sxlS1pRBJ-WKiV4mIQ&_nc_oc=AdlK74zWnBFLBc2BIbCT_wSFpLpl_6Oj0ikHBNGG5q-7XykgulkP7GVUCCGnyOJ7MP0&ccb=10-5&oh=00_AfIH9m7sqExARwc0a4TUA_DgF1BkRCYz2VTaKZQsJri5kQ&oe=6844309C&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8ZZ9MXwsJWwgZlpyistS2-VMGP1uRtNz…]8;;\ │ EbVos4devuYFjQGmMPDlA7 │  1280 │ 4.896778 │ 52.381290 │
# └──────────────────┴───────────┴──────────────┴─────────────┴───────────────┴───────────────┴───────────────────┴────────────────────────┴───────────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┴───────────────────────────────────────────────────┴────────┴─────────┴────────┴───────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴────────────────────────┴───────┴──────────┴───────────┘

# %% [markdown]
# ### Visualise Data

# %% [markdown]
# Now that we have subsetted the data, we might want to see where the images we want to download are located and if we have good coverage of the city.
#
# First, the table needs to be converted to a geopandas dataframe and given an appropriate CRS.

# %%
pdf = df.to_pandas()
gdf = gpd.GeoDataFrame(pdf, geometry=gpd.points_from_xy(pdf.lon, pdf.lat))
gdf.set_crs("EPSG:4326", allow_override=True, inplace=True)
gdf.head(5)
# Out:
#                  id   altitude  atomic_scale  camera_type    captured_at  \
# 0  2172293386289344  50.098000      0.802639      fisheye  1683741159000
# 1  2214473772041985   2.113821    243.100007  perspective  1651584681027
# 2  2201783443340884  51.612000      1.035112      fisheye  1687547597000
# 3  2199564663716780  49.451000      0.997227      fisheye  1717398810000
# 4  3269640993308803  70.100000      0.449626  perspective  1657637093000
#
#    compass_angle  computed_altitude  computed_compass_angle  \
# 0     348.078913           2.665259              345.561079
# 1       4.766724           1.999902               15.067546
# 2     355.487000           1.194646              343.071082
# 3      39.041000           2.504714               48.565448
# 4     132.172247           0.114532              132.466114
#
#                                    computed_geometry  \
# 0  {'coordinates': [4.8958046296203, 52.371904561...
# 1  {'coordinates': [4.890289282911, 52.3653388728...
# 2  {'coordinates': [4.9108905152262, 52.364557475...
# 3  {'coordinates': [4.8889699567427, 52.368443664...
# 4  {'coordinates': [4.8967783437549, 52.381289687...
#
#                                    computed_rotation  ...   make  \
# 0  [1.5538203792879, 0.22772272942943, -0.1673816...  ...  GoPro
# 1  [1.5653501585152, -0.17028310687785, 0.2428234...  ...  Apple
# 2  [1.5102157453911, 0.26171299179499, -0.1973719...  ...  GoPro
# 3  [1.3031780175287, -0.70662946877827, 0.5710038...  ...  GoPro
# 4  [0.93192892253876, -2.0494630200259, 1.4633695...  ...  Tesla
#
#            model                                      thumb_256_url  \
# 0    HERO7 Black  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  iPhone 13 Pro  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 2    HERO7 Black  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 3    HERO7 Black  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 4           none  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                       thumb_1024_url  \
# 0  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 2  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 3  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                       thumb_2048_url  \
# 0  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 2  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 3  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                   thumb_original_url                sequence  \
# 0  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  hgz5csEuyw4HqBGUC1XZQl
# 1  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  EXfdPov1FJBupzq02U9IeV
# 2  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  fz4WBbMQTVZ1Gqoe7PdKjX
# 3  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  WHX0bGlqYRSDUtZF13wdON
# 4  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  EbVos4devuYFjQGmMPDlA7
#
#   width       lon        lat
# 0  4000  4.895805  52.371905
# 1  4032  4.890289  52.365339
# 2  4000  4.910891  52.364557
# 3  4000  4.888970  52.368444
# 4  1280  4.896778  52.381290
#
# [5 rows x 24 columns]

# %% [markdown]
# Then we can plot the image locations:

# %%
ax = gdf.plot(column='uuid', color='red', markersize=3, figsize=(6, 6), alpha=0.5)
contextily.add_basemap(ax, crs=gdf.crs, source=contextily.providers.nlmaps.standaard)

# %% [markdown]
# ### Download images

# %% [markdown]
# Let's first download and visualise a single image:

# %%
image = gdf.iloc[0]
filename = mp.download_image(image.id, image.thumb_1024_url, overwrite=True)
Image.open(filename)

# %% [markdown]
# Now let's do this for the first 10 images of our dataset:

# %%
df_sample = gdf.iloc[:5]
image_ids = df_sample.id
urls = df_sample.thumb_1024_url
paths = mp.download_images(image_ids, urls)

# %% [markdown]
# For examples of other data sources, check out the [documentation section](../examples/use_data_sources.ipynb) related to downloading images.

# %% [markdown]
# ### Segment images
#
# We can load various models and apply them to the image data that we have loaded or generated so far. Currently, Streetscapes supports two segmentation models:
#
# - `MaskFormer`: A relatively small and nimble model that recognises objects from a fixed number of categories.
# - `DinoSAM`: A combination of two independent models that work together to perform instance segmentation simply by providing a prompt. It is much more flexible than `MaskFormer` in that it recognises *arbitrary categories*; however, it is much slower.
#
# In this tutorial we will use `DinoSAM`, for a more in-depth tutorial of segmentation with different models, go [here](../examples/segmentation.ipynb). First, we load the model in a similar manner to data sources. Models are spawned globally and can be reused across multiple workspaces to minimise memory consumption for potentially large models.

# %%
model = DinoSAM()

# %% [markdown]
# We define the categories of objects that we would like to look for in the images that we are segmenting. Categories are defined hierarchically as a nested dictionary. Subcategories (such as `window` and `door` below) will be identified as separate categories, but the pixels that they occupy will be subtracted from ones attributed to their parent (here, `building`). In this way, it is possible to extract building façades excluding windows and doors. Internally, this nested dictionary is flattened, and any overlaps are handled after instances of the corresponding categories have been identified.

# %%
labels = {
    "building": {
        "window": None,
        "door": None,
    },
    "vegetation": None,
    "car": None,
    "truck": None,
    "road": None,
}

# %% [markdown]
# Segment a list of images provided as file paths. Here, we use our subset that we created above. A batch size (defaulting to `1`) can be specified to speed up the segmentation, but here we use a batch size of 1 to show the progress more clearly.

# %%
# TODO: Make this function more flexible so columns names can be set
segmentations = model.segment(paths, labels)
segmentations

# %% [markdown]
# The masks and the instances are saved as separate files with the same name as the input image but in different formats (NumPy archived arrays and Parquet files, respectively) so that they can be loaded later together. Here, we print the name of the file containing the mask for the first segmented image.

# %%
segmentation = segmentations[0]
segmentation

# %%
segmentation.get_instance_labels()

# %% [markdown]
# Show the distinct categories (out of the ones that we requested) identified by this model.

# %%
segmentation.get_instance_labels(as_table=True).select('label').distinct()

# %% [markdown]
# Visualise the parts of the image corresponding to some object categories of interest (here, we ask for everything that is labelled as a `building`).

# %%
segmentation.image_path

# %%
masks = segmentation.get_masks()

# %%
segmentation.visualise(['building', "window"])

# %% [markdown]
# If the `visualise()` method is called without an argument, all the identified categories are visualised.

# %%
segmentation.visualise()

# %% [markdown]
# We can also extract instances for individual categories and and visualise them in isolation.

# %%
buildings = segmentation.get_instances("building", exclude=["window", "door"])

# %% [markdown]
# We will extract the first `building` instance to make working with the instance a bit easier. Here, we also visualise the instance using the built-in `visualise()` method to show the instance in isolation, with the remainder of the image blanked out.

# %%
building = buildings[0]
building.visualise()

# %% [markdown]
# We can also visualise a specific channel of the image. Here, we visualise the red channel, which corresponds to index `0`.

# %%
building.visualise(channel=0)

# %% [markdown]
# We can also extract a NumPy array representing the pixel values that correspond to the instance by using the built-in `masked()` method. This method also allows us to extract a specific channel. The result can then be used to compute statistics, such as `mean()`.

# %%
masked = building.masked()
masked_red = building.masked(channel=0)

# %% [markdown]
# For instance, we can easily compute the 'mean colour' of the instance...

# %%
masked_mean = masked.mean(axis = 0)
masked_mean

# %% [markdown]
# ...or the mean for a specific channel:

# %%
masked_red_mean = masked_red.mean(axis=0)
masked_red_mean

# %% [markdown]
# We can also perform the same operation on an HSV version of the image by passing `hsv=True` to the `masked()` method:

# %%
masked_hsv = building.masked(hsv=True)
masked_hsv

# %%
masked_v = building.masked(hsv=True, channel=2)
masked_v

# %% [markdown]
# A built-in method is provided for convenience to extract the value (brightness) of the instance. It performs the same computation as the cell above.

# %%
brightness = building.brightness()
brightness.mean()

# %% [markdown]
# ### Calculate statistics

# %%
# Compute albedo (mean V from HSV)
building_means = []
for seg in segmentations:
    buildings = seg.get_instances("building", exclude=["window", "door"], merge = True)
    building_means.append(buildings.brightness().mean())

# %%
building_means

# %%
# TODO:
# instance.get_material()

# TODO:
# Add statistics to metadata

# TODO:
# Add model parameters to the segmentation metadata for each image (parquet file)
