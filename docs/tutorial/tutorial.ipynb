# %% [markdown]
# # Streetscapes workspaces
#
# This notebook provides an example of a workflow using Streetscapes. You can load different data sources and ML models, process streetview images and save generated data to your workspace.
#
# This notebook includes the following steps:
#
# - [Define a workspace](#define-a-workspace)
# - [Obtaining images](#obtaining-images)
# - [Subset data](#2---subset-data)
# - [Visualise data](#3---visualise-data)
# - [Download images](#4---download-images)
# - [Segment images](#5---segment-images)
# - [Calculate statistics](#6---calculate-statistics)

# %% [markdown]
# ### Libraries

# %%
# --------------------------------------
import warnings

warnings.filterwarnings("ignore")

# --------------------------------------
import ibis

ibis.options.interactive = True

# --------------------------------------
import geopandas as gpd

# --------------------------------------
import contextily

# --------------------------------------
from PIL import Image

# --------------------------------------
from streetscapes.sources import Mapillary
from streetscapes.models import DinoSAM
from streetscapes.streetview import SVWorkspace

# %% [markdown]
# ### Define a workspace

# %% [markdown]
# Streetscapes has a workspace functionality to facilitate data analysis. Within this workspace, downloaded data, images, segmented masks and analysis for a certain project are self contained and reproducible.
#
# <span style="color:grey;"><i> Note: You can also pass the path to an `.env` file containing configuration options for the workspace. By default, the workspace looks for an `.env` file inside the workspace directory, and if it doesn't exist, it walks the parent tree until it finds one or it reaches the root of the file system. Environment variables are also recognised automatically.</i></span>
#
# First, create a workspace or load an existing one. In this tutorial, we will be doing an analysis of Amsterdam, so we are naming our workspace "Amsterdam":

# %%
ws = SVWorkspace("./Amsterdam")

# %% [markdown]
# If we show the contents of the workspace directory, we can see that a subdirectory for Amsterdam was created as well as a [duckdb](https://duckdb.org/) metadata file.

# %%
ws.show_contents()
# Out:
# Amsterdam/
# ├─.gitignore
# └─metadata.db

# %% [markdown]
# Let's now look at where this new workspace is located:

# %%
workspace_path = ws.get_workspace_path()
workspace_path
# Out:
# PosixPath('/home/hobbes/code/github/streetscapes/remote/docs/tutorial/Amsterdam')

# %% [markdown]
# ### Obtaining images

# %% [markdown]
# Now let's add which source of images we would like to use. Possible are sources are: [Mapillary](https://www.mapillary.com/), [Kartaview](https://kartaview.org/) and [Amsterdam Open Panorama](https://amsterdam.github.io/projects/open-panorama/). It is also possible to use [Global Streetscapes](https://ual.sg/project/global-streetscapes/) as a data source.
#
# In this example, we will use Mapillary.
#
# <span style="color:red;">NOTE</span>: To use Mapillary, you need to have an API token, which you can obtain from the [Mapillary developer portal](https://www.mapillary.com/developer).
# Store the token in an `.env` file inside your workspace directory as follows:
#
# ```
# MAPILLARY_TOKEN=<your-API-token>
# ```

# %%
mp = Mapillary(ws.env)

# %% [markdown]
# We can then view where these data sources are located. This will be where all images, instances and masks will be stored.

# %%
mp
# Out:
# Mapillary(root_dir='~/.cache/huggingface/assets/streetscapes/images/mapillary')

# %% [markdown]
# Let's have a more detailed look into the data sources that we have loaded. We will find the available images based on a bounding box.

# %%
bbox = [4.883466,52.361790,4.916210,52.381494]
df = mp.fetch_image_ids(bbox=bbox)
hdf = df.head(5)
hdf
# Out:
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ id               ┃ altitude  ┃ atomic_scale ┃ camera_type ┃ captured_at   ┃ compass_angle ┃ computed_altitude ┃ computed_compass_angle ┃ computed_geometry                                 ┃ computed_rotation                            ┃ exif_orientation ┃ geometry                                          ┃ height ┃ is_pano ┃ make   ┃ model         ┃ thumb_256_url                                                                    ┃ thumb_1024_url                                                                   ┃ thumb_2048_url                                                                   ┃ thumb_original_url                                                               ┃ sequence               ┃ width ┃ lon      ┃ lat       ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ string           │ float64   │ float64      │ string      │ int64         │ float64       │ float64           │ float64                │ struct<coordinates: array<float64>, type: string> │ array<float64>                               │ int64            │ struct<coordinates: array<float64>, type: string> │ int64  │ boolean │ string │ string        │ string                                                                           │ string                                                                           │ string                                                                           │ string                                                                           │ string                 │ int64 │ float64  │ float64   │
# ├──────────────────┼───────────┼──────────────┼─────────────┼───────────────┼───────────────┼───────────────────┼────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┼───────────────────────────────────────────────────┼────────┼─────────┼────────┼───────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼────────────────────────┼───────┼──────────┼───────────┤
# │ 3606264719698396 │ 45.249000 │     0.993570 │ fisheye     │ 1688045161000 │    130.593000 │          0.338125 │             140.129027 │ {'coordinates': [...], 'type': 'Point'}           │ [0.61527062241475, -1.6411650863089, ... +1] │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro  │ HERO7 Black   │ ]8;id=710524;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTfovrhnDSVDyT_UM8fBDBeiOmkt05jGyqzFukkGHo1W-EuauJhaiJbRy33Fv3WYETYLVKgTU4c9Mfderl3xuSLg9DnSINr5AjgbKh9UdPD43Nr0l4dTIJQ?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adl5cQY5bM9u32WKQZbaUtUwyG0v9yX1zzbR0xPjAd9KRUO3b-DKdGllN4Mlm0KNbx0&ccb=10-5&oh=00_AfLOoy3Pay8xOAwXteHrH6ox3zKQR6teDxl-TrTvvP2saw&oe=6842DBE6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTf…]8;;\ │ ]8;id=60168;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTfovrhnDSVDyT_UM8fBDBeiOmkt05jGyqzFukkGHo1W-EuauJhaiJbRy33Fv3WYETYLVKgTU4c9Mfderl3xuSLg9DnSINr5AjgbKh9UdPD43Nr0l4dTIJQ?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adl5cQY5bM9u32WKQZbaUtUwyG0v9yX1zzbR0xPjAd9KRUO3b-DKdGllN4Mlm0KNbx0&ccb=10-5&oh=00_AfKJIzpPb6Qh48po0Gr6u-bV3_M0YZYnfPofBVZGfrF1yQ&oe=6842DBE6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTf…]8;;\ │ ]8;id=169661;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTfovrhnDSVDyT_UM8fBDBeiOmkt05jGyqzFukkGHo1W-EuauJhaiJbRy33Fv3WYETYLVKgTU4c9Mfderl3xuSLg9DnSINr5AjgbKh9UdPD43Nr0l4dTIJQ?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adl5cQY5bM9u32WKQZbaUtUwyG0v9yX1zzbR0xPjAd9KRUO3b-DKdGllN4Mlm0KNbx0&ccb=10-5&oh=00_AfL1WYOXfeF5j4aQF3DBIxge68A9LmFXrx3mrV5fOxt9Jg&oe=6842DBE6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTf…]8;;\ │ ]8;id=839765;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTfovrhnDSVDyT_UM8fBDBeiOmkt05jGyqzFukkGHo1W-EuauJhaiJbRy33Fv3WYETYLVKgTU4c9Mfderl3xuSLg9DnSINr5AjgbKh9UdPD43Nr0l4dTIJQ?edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adl5cQY5bM9u32WKQZbaUtUwyG0v9yX1zzbR0xPjAd9KRUO3b-DKdGllN4Mlm0KNbx0&ccb=10-5&oh=00_AfKaVTlTbffVcSzaOLKBz5D2yPXlBRNf1rLwyNTppAb_xA&oe=6842DBE6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8f7--EWZiiC8jR3Od7EAbkwZM4CbznTf…]8;;\ │ m0gFJCjtp1Ihceu3zqVrGd │  4000 │ 4.895756 │ 52.378894 │
# │ 1624132314867371 │ 49.359000 │     1.031894 │ fisheye     │ 1725003958500 │     16.375000 │          1.141542 │              17.750246 │ {'coordinates': [...], 'type': 'Point'}           │ [1.4073890234063, -0.2080458824812, ... +1]  │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro  │ HERO7 Black   │ ]8;id=71429;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgbqvQfsQ2z7A4tLzuZ1MeSFum2k7Z3LqKyNCkc6VeoWS1w5NrL1s14WzwY_nbvSh2KHvcj9s2giGb8BWSZ_spo3yBhQNcE1QOmegTjXtmKO_02AJU4O8B_4?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adn4IEoKpLuhUMZKUMZZDnppMHxZS9_GVJoUye-Mi9CPX1hPabEpkRZcBmwYJVpzHGw&ccb=10-5&oh=00_AfIruepc9ofs4yCRX-jayqBJlLFz_C0AUtoTdq9yDVemxw&oe=6842C4C6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgb…]8;;\ │ ]8;id=745987;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgbqvQfsQ2z7A4tLzuZ1MeSFum2k7Z3LqKyNCkc6VeoWS1w5NrL1s14WzwY_nbvSh2KHvcj9s2giGb8BWSZ_spo3yBhQNcE1QOmegTjXtmKO_02AJU4O8B_4?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adn4IEoKpLuhUMZKUMZZDnppMHxZS9_GVJoUye-Mi9CPX1hPabEpkRZcBmwYJVpzHGw&ccb=10-5&oh=00_AfJ66aIiIQHxcjtUSWv0xLYDj9dd_sSY4eVdnjA185OmwA&oe=6842C4C6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgb…]8;;\ │ ]8;id=973004;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgbqvQfsQ2z7A4tLzuZ1MeSFum2k7Z3LqKyNCkc6VeoWS1w5NrL1s14WzwY_nbvSh2KHvcj9s2giGb8BWSZ_spo3yBhQNcE1QOmegTjXtmKO_02AJU4O8B_4?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adn4IEoKpLuhUMZKUMZZDnppMHxZS9_GVJoUye-Mi9CPX1hPabEpkRZcBmwYJVpzHGw&ccb=10-5&oh=00_AfJu2wdtiNBHEooqPOfC5A3EXlYRoMPps-9yCvoiCswIQA&oe=6842C4C6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgb…]8;;\ │ ]8;id=140668;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgbqvQfsQ2z7A4tLzuZ1MeSFum2k7Z3LqKyNCkc6VeoWS1w5NrL1s14WzwY_nbvSh2KHvcj9s2giGb8BWSZ_spo3yBhQNcE1QOmegTjXtmKO_02AJU4O8B_4?edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adn4IEoKpLuhUMZKUMZZDnppMHxZS9_GVJoUye-Mi9CPX1hPabEpkRZcBmwYJVpzHGw&ccb=10-5&oh=00_AfIk_Sh-E5Ja6sHFd_GvtS7hXCFcYY-422ce_eYCz9o4zg&oe=6842C4C6&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_0QqUB9P3EIZXfwn8Ljx2RGn7J0yslgb…]8;;\ │ Rjqh8cPyrSNa4EdJb3tmVn │  4000 │ 4.895756 │ 52.378894 │
# │ 1775632102832224 │ 56.953000 │     1.004727 │ fisheye     │ 1683207699000 │    138.713251 │          5.135112 │             124.612510 │ {'coordinates': [...], 'type': 'Point'}           │ [0.69865052754303, -1.617240067212, ... +1]  │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro  │ HERO7 Black   │ ]8;id=881641;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaNJH-pABaqHhNQFUN5rQ0zGttW8Uhv8nGuN1uUePSotDlSZCYlPrB-bsaFCjR9qHcB5grr-uCGnqpcWjVketkCEqvxFDgeWHtmfrg9a69aP0XloznvSJJYY?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adk-HxnNZtWlXFO-sglGX9xdjWXPEcVIcpPeIHPf1vkfVTTPqUErEnkvvQ3D1m03c30&ccb=10-5&oh=00_AfIpht-Lp162_-fSU3-nalTRXU7Voo1ejPbAi1fK667IIQ&oe=6842DAF7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaN…]8;;\ │ ]8;id=12418;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaNJH-pABaqHhNQFUN5rQ0zGttW8Uhv8nGuN1uUePSotDlSZCYlPrB-bsaFCjR9qHcB5grr-uCGnqpcWjVketkCEqvxFDgeWHtmfrg9a69aP0XloznvSJJYY?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adk-HxnNZtWlXFO-sglGX9xdjWXPEcVIcpPeIHPf1vkfVTTPqUErEnkvvQ3D1m03c30&ccb=10-5&oh=00_AfLKDtu5LZoHEWEbSnEFZgK1s5AIqXVLWu0JXwKR97AI4A&oe=6842DAF7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaN…]8;;\ │ ]8;id=832472;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaNJH-pABaqHhNQFUN5rQ0zGttW8Uhv8nGuN1uUePSotDlSZCYlPrB-bsaFCjR9qHcB5grr-uCGnqpcWjVketkCEqvxFDgeWHtmfrg9a69aP0XloznvSJJYY?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adk-HxnNZtWlXFO-sglGX9xdjWXPEcVIcpPeIHPf1vkfVTTPqUErEnkvvQ3D1m03c30&ccb=10-5&oh=00_AfLkNLJysb9frNX5bymA1uPdat4zCzN2wDZ5MIGEf1yywA&oe=6842DAF7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaN…]8;;\ │ ]8;id=926632;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaNJH-pABaqHhNQFUN5rQ0zGttW8Uhv8nGuN1uUePSotDlSZCYlPrB-bsaFCjR9qHcB5grr-uCGnqpcWjVketkCEqvxFDgeWHtmfrg9a69aP0XloznvSJJYY?edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=Adk-HxnNZtWlXFO-sglGX9xdjWXPEcVIcpPeIHPf1vkfVTTPqUErEnkvvQ3D1m03c30&ccb=10-5&oh=00_AfLFZAIvtwq93FNYUdGVTEkLkenQUieX6RhfBKDzZex9zQ&oe=6842DAF7&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An8by2uatxEr3DxyndOGqUNdDCmEBP3SaN…]8;;\ │ 51A8R7XN2syMLivHKfCQTP │  4000 │ 4.895756 │ 52.378894 │
# │ 1599878267189133 │ 46.973000 │     0.999805 │ fisheye     │ 1687536672000 │    131.063000 │          0.498841 │             130.900698 │ {'coordinates': [...], 'type': 'Point'}           │ [0.64643400382323, -1.551034079143, ... +1]  │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3000 │ False   │ GoPro  │ HERO7 Black   │ ]8;id=830417;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKatzniCekhSkxQyGJ42bsTF9C2XiDPdakkHOgoBc5LVl3d3knXkb1VFHKKZypyJJ-lbPMtvO9ir2PsmIToj-J-DbJQkqjsO0-oIjph9k8wn07GRg8b8vAA?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdlTQ1vgSUnqtw0iuRKnOzK4la-44BeOlCneuotbpGQPWezGSENMXqTu1gORjKCbvL8&ccb=10-5&oh=00_AfKNfCREJlD5Sj9kj_ID8QHXkm2aNSPOisx5SWL2WeTo4w&oe=6842F0BC&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKa…]8;;\ │ ]8;id=357751;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKatzniCekhSkxQyGJ42bsTF9C2XiDPdakkHOgoBc5LVl3d3knXkb1VFHKKZypyJJ-lbPMtvO9ir2PsmIToj-J-DbJQkqjsO0-oIjph9k8wn07GRg8b8vAA?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdlTQ1vgSUnqtw0iuRKnOzK4la-44BeOlCneuotbpGQPWezGSENMXqTu1gORjKCbvL8&ccb=10-5&oh=00_AfIji2tR0GMylCv-_wesRlonzFWfM_9nE5pNGbafAc11_Q&oe=6842F0BC&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKa…]8;;\ │ ]8;id=596656;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKatzniCekhSkxQyGJ42bsTF9C2XiDPdakkHOgoBc5LVl3d3knXkb1VFHKKZypyJJ-lbPMtvO9ir2PsmIToj-J-DbJQkqjsO0-oIjph9k8wn07GRg8b8vAA?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdlTQ1vgSUnqtw0iuRKnOzK4la-44BeOlCneuotbpGQPWezGSENMXqTu1gORjKCbvL8&ccb=10-5&oh=00_AfJeJ3P3F2hsNtmoaCsT-2fN3XoOoXet1sXPWgHszWrpJQ&oe=6842F0BC&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKa…]8;;\ │ ]8;id=135371;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKatzniCekhSkxQyGJ42bsTF9C2XiDPdakkHOgoBc5LVl3d3knXkb1VFHKKZypyJJ-lbPMtvO9ir2PsmIToj-J-DbJQkqjsO0-oIjph9k8wn07GRg8b8vAA?edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdlTQ1vgSUnqtw0iuRKnOzK4la-44BeOlCneuotbpGQPWezGSENMXqTu1gORjKCbvL8&ccb=10-5&oh=00_AfLDJaUD-wR_OOs71ljEnGGHw9kaS5HrlzoW0uQ_iXyR9w&oe=6842F0BC&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An9QlczVJP2qWgPOj2AqBK3FLdw0vuMCKa…]8;;\ │ zoVl7u4aNqpRHktws6i32g │  4000 │ 4.895756 │ 52.378894 │
# │ 1647053795869959 │  4.052956 │     1.003028 │ perspective │ 1725955253655 │     85.825478 │          1.663176 │              93.949072 │ {'coordinates': [...], 'type': 'Point'}           │ [1.0466238583851, -1.1145729295448, ... +1]  │                1 │ {'coordinates': [...], 'type': 'Point'}           │   3024 │ False   │ Apple  │ iPhone 13 Pro │ ]8;id=481265;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cwuEMCcIIRRG1giKwWzJtHvya0a1Btm2fj4fr6NGDZll6pOHhx9E5d5jcwmHPQWA8kGSDi1eCEdpH048Sx4nLG97X3iSn0hPJawABh-Xu-OYa61rKTBp4qk?stp=s256x192&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdmUF0HhqQ0X8sd6CUeLiBFzvVUMSbyDDQCt7HEQirvcsr4rw6WDZHVPY1YVgaiogHg&ccb=10-5&oh=00_AfIek8KEAxZ7aUlzZ9dMTXH14cjLVrvZRB4hUDcoznN0pw&oe=6842E015&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cw…]8;;\ │ ]8;id=220137;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cwuEMCcIIRRG1giKwWzJtHvya0a1Btm2fj4fr6NGDZll6pOHhx9E5d5jcwmHPQWA8kGSDi1eCEdpH048Sx4nLG97X3iSn0hPJawABh-Xu-OYa61rKTBp4qk?stp=s1024x768&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdmUF0HhqQ0X8sd6CUeLiBFzvVUMSbyDDQCt7HEQirvcsr4rw6WDZHVPY1YVgaiogHg&ccb=10-5&oh=00_AfJOvuwCe7OYT7TbJNO05YY2oLmuJ9K5LaP-Rv99yiK-sw&oe=6842E015&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cw…]8;;\ │ ]8;id=97983;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cwuEMCcIIRRG1giKwWzJtHvya0a1Btm2fj4fr6NGDZll6pOHhx9E5d5jcwmHPQWA8kGSDi1eCEdpH048Sx4nLG97X3iSn0hPJawABh-Xu-OYa61rKTBp4qk?stp=s2048x1536&edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdmUF0HhqQ0X8sd6CUeLiBFzvVUMSbyDDQCt7HEQirvcsr4rw6WDZHVPY1YVgaiogHg&ccb=10-5&oh=00_AfL_GfEdfT4tSVwI7__omwtCHGwWNACRp9MPUP0Bxcm8cQ&oe=6842E015&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cw…]8;;\ │ ]8;id=766957;https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cwuEMCcIIRRG1giKwWzJtHvya0a1Btm2fj4fr6NGDZll6pOHhx9E5d5jcwmHPQWA8kGSDi1eCEdpH048Sx4nLG97X3iSn0hPJawABh-Xu-OYa61rKTBp4qk?edm=AOnQwmMEAAAA&_nc_gid=ID4OdchfI980M9kUh8dfxA&_nc_oc=AdmUF0HhqQ0X8sd6CUeLiBFzvVUMSbyDDQCt7HEQirvcsr4rw6WDZHVPY1YVgaiogHg&ccb=10-5&oh=00_AfKMuDotmV2nxiFpavDAc9gk6HP6kpRLUWIBeFXL2DS1JQ&oe=6842E015&_nc_sid=201bca\https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/An_7eSCr_cUU3URuyJFW1h5h_BUGXPN5cw…]8;;\ │ UEL1RQkvsZ4gniV3wx7p80 │  4032 │ 4.895756 │ 52.378894 │
# └──────────────────┴───────────┴──────────────┴─────────────┴───────────────┴───────────────┴───────────────────┴────────────────────────┴───────────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┴───────────────────────────────────────────────────┴────────┴─────────┴────────┴───────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴────────────────────────┴───────┴──────────┴───────────┘

# %%
hdf.select("lon", "lat")
# Out:
# ┏━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ lon      ┃ lat       ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━┩
# │ float64  │ float64   │
# ├──────────┼───────────┤
# │ 4.895756 │ 52.378894 │
# │ 4.901007 │ 52.372991 │
# │ 4.886736 │ 52.377883 │
# │ 4.912260 │ 52.371616 │
# │ 4.901733 │ 52.376942 │
# └──────────┴───────────┘

# %% [markdown]
# ### Visualise Data

# %% [markdown]
# Now that we have subsetted the data, we might want to see where the images we want to download are located and if we have good coverage of the city.
#
# First, the table needs to be converted to a geopandas dataframe and given an appropriate CRS.

# %%
pdf = df.to_pandas()
gdf = gpd.GeoDataFrame(pdf, geometry=gpd.points_from_xy(pdf.lon, pdf.lat))
gdf.set_crs("EPSG:4326", allow_override=True, inplace=True)
gdf.head(5)
# Out:
#                  id   altitude  atomic_scale  camera_type    captured_at  \
# 0  3606264719698396  45.249000      0.993570      fisheye  1688045161000
# 1  1624132314867371  49.359000      1.031894      fisheye  1725003958500
# 2  1775632102832224  56.953000      1.004727      fisheye  1683207699000
# 3  1599878267189133  46.973000      0.999805      fisheye  1687536672000
# 4  1647053795869959   4.052956      1.003028  perspective  1725955253655
#
#    compass_angle  computed_altitude  computed_compass_angle  \
# 0     130.593000           0.338125              140.129027
# 1      16.375000           1.141542               17.750246
# 2     138.713251           5.135112              124.612510
# 3     131.063000           0.498841              130.900698
# 4      85.825478           1.663176               93.949072
#
#                                    computed_geometry  \
# 0  {'coordinates': [4.8957560111867, 52.378894255...
# 1  {'coordinates': [4.9010074934734, 52.372990945...
# 2  {'coordinates': [4.8867360096763, 52.377882600...
# 3  {'coordinates': [4.912259640169, 52.3716164773...
# 4  {'coordinates': [4.9017325143078, 52.376942058...
#
#                                    computed_rotation  ...   make  \
# 0  [0.61527062241475, -1.6411650863089, 1.9611490...  ...  GoPro
# 1  [1.4073890234063, -0.2080458824812, 0.26940239...  ...  GoPro
# 2  [0.69865052754303, -1.617240067212, 1.56258013...  ...  GoPro
# 3  [0.64643400382323, -1.551034079143, 1.77870471...  ...  GoPro
# 4  [1.0466238583851, -1.1145729295448, 1.35059485...  ...  Apple
#
#            model                                      thumb_256_url  \
# 0    HERO7 Black  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 1    HERO7 Black  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 2    HERO7 Black  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 3    HERO7 Black  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  iPhone 13 Pro  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                       thumb_1024_url  \
# 0  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 2  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 3  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                       thumb_2048_url  \
# 0  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 1  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 2  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 3  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
# 4  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...
#
#                                   thumb_original_url                sequence  \
# 0  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  m0gFJCjtp1Ihceu3zqVrGd
# 1  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  Rjqh8cPyrSNa4EdJb3tmVn
# 2  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  51A8R7XN2syMLivHKfCQTP
# 3  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  zoVl7u4aNqpRHktws6i32g
# 4  https://scontent-ams2-1.xx.fbcdn.net/m1/v/t6/A...  UEL1RQkvsZ4gniV3wx7p80
#
#   width       lon        lat
# 0  4000  4.895756  52.378894
# 1  4000  4.895756  52.378894
# 2  4000  4.895756  52.378894
# 3  4000  4.895756  52.378894
# 4  4032  4.895756  52.378894
#
# [5 rows x 24 columns]

# %% [markdown]
# Then we can plot the image locations:

# %%
ax = gdf.plot(column='uuid', color='red', markersize=3, figsize=(6, 6), alpha=0.5)
contextily.add_basemap(ax, crs=gdf.crs, source=contextily.providers.nlmaps.standaard)

# %% [markdown]
# ### Download images

# %% [markdown]
# Let's first download and visualise a single image:

# %%
image = gdf.iloc[0]
filename = mp.download_image(image.id, image.thumb_1024_url, overwrite=True)
Image.open(filename)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768>

# %% [markdown]
# Now let's do this for the first 10 images of our dataset:

# %%
df_sample = gdf.iloc[:5]
image_ids = df_sample.id
urls = df_sample.thumb_1024_url
paths = mp.download_images(image_ids, urls)
# Out:
# Downloading images | mapillary | Done: 100%|██████████| 5/5 [00:01<00:00,  3.01it/s]

# %% [markdown]
# For examples of other data sources, check out the [documentation section](../examples/use_data_sources.ipynb) related to downloading images.

# %% [markdown]
# ### Segment images
#
# We can load various models and apply them to the image data that we have loaded or generated so far. Currently, Streetscapes supports two segmentation models:
#
# - `MaskFormer`: A relatively small and nimble model that recognises objects from a fixed number of categories.
# - `DinoSAM`: A combination of two independent models that work together to perform instance segmentation simply by providing a prompt. It is much more flexible than `MaskFormer` in that it recognises *arbitrary categories*; however, it is much slower.
#
# In this tutorial we will use `DinoSAM`, for a more in-depth tutorial of segmentation with different models, go [here](../examples/segmentation.ipynb). First, we load the model in a similar manner to data sources. Models are spawned globally and can be reused across multiple workspaces to minimise memory consumption for potentially large models.

# %%
model = DinoSAM()

# %% [markdown]
# We define the categories of objects that we would like to look for in the images that we are segmenting. Categories are defined hierarchically as a nested dictionary. Subcategories (such as `window` and `door` below) will be identified as separate categories, but the pixels that they occupy will be subtracted from ones attributed to their parent (here, `building`). In this way, it is possible to extract building façades excluding windows and doors. Internally, this nested dictionary is flattened, and any overlaps are handled after instances of the corresponding categories have been identified.

# %%
labels = {
    "building": {
        "window": None,
        "door": None,
    },
    "vegetation": None,
    "car": None,
    "truck": None,
    "road": None,
}

# %% [markdown]
# Segment a list of images provided as file paths. Here, we use our subset that we created above. A batch size (defaulting to `1`) can be specified to speed up the segmentation, but here we use a batch size of 1 to show the progress more clearly.

# %%
# TODO: Make this function more flexible so columns names can be set
segmentations = model.segment(paths, labels)
segmentations
# Out:
# Segmenting images...: 100%|██████████| 1/1 [01:31<00:00, 91.31s/it]
# [SVSegmentation(path=/home/hobbes/.cache/huggingface/assets/streetscapes/images/mapillary/segmentations/dinosam/3606264719698396.parquet,
#  SVSegmentation(path=/home/hobbes/.cache/huggingface/assets/streetscapes/images/mapillary/segmentations/dinosam/1624132314867371.parquet,
#  SVSegmentation(path=/home/hobbes/.cache/huggingface/assets/streetscapes/images/mapillary/segmentations/dinosam/1775632102832224.parquet,
#  SVSegmentation(path=/home/hobbes/.cache/huggingface/assets/streetscapes/images/mapillary/segmentations/dinosam/1599878267189133.parquet,
#  SVSegmentation(path=/home/hobbes/.cache/huggingface/assets/streetscapes/images/mapillary/segmentations/dinosam/1647053795869959.parquet]

# %% [markdown]
# The masks and the instances are saved as separate files with the same name as the input image but in different formats (NumPy archived arrays and Parquet files, respectively) so that they can be loaded later together. Here, we print the name of the file containing the mask for the first segmented image.

# %%
segmentation = segmentations[0]
segmentation
# Out:
# SVSegmentation(path=/home/hobbes/.cache/huggingface/assets/streetscapes/images/mapillary/segmentations/dinosam/3606264719698396.parquet

# %%
segmentation.get_instance_labels()
# Out:
# {1: 'car',
#  2: 'car',
#  3: 'window',
#  4: 'window',
#  5: 'door',
#  6: 'car',
#  7: 'building',
#  8: 'window',
#  9: 'window',
#  10: 'window',
#  11: 'vegetation',
#  12: 'road',
#  13: 'window',
#  14: 'window',
#  15: 'window',
#  16: 'building',
#  17: 'window',
#  18: 'building',
#  19: 'window',
#  20: 'road'}

# %% [markdown]
# Show the distinct categories (out of the ones that we requested) identified by this model.

# %%
segmentation.get_instance_labels(as_table=True).select('label').distinct()
# Out:
# ┏━━━━━━━━━━━━┓
# ┃ label      ┃
# ┡━━━━━━━━━━━━┩
# │ string     │
# ├────────────┤
# │ window     │
# │ door       │
# │ building   │
# │ road       │
# │ car        │
# │ vegetation │
# └────────────┘

# %% [markdown]
# Visualise the parts of the image corresponding to some object categories of interest (here, we ask for everything that is labelled as a `building`).

# %%
segmentation.image_path
# Out:
# PosixPath('/home/hobbes/.cache/huggingface/assets/streetscapes/images/mapillary/3606264719698396.jpeg')

# %%
masks = segmentation.get_masks()

# %%
segmentation.visualise(['building', "window"])
# Out:
# (<Figure size 1600x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# If the `visualise()` method is called without an argument, all the identified categories are visualised.

# %%
segmentation.visualise()
# Out:
# (<Figure size 1600x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# We can also extract instances for individual categories and and visualise them in isolation.

# %%
buildings = segmentation.get_instances("building", exclude=["window", "door"])

# %% [markdown]
# We will extract the first `building` instance to make working with the instance a bit easier. Here, we also visualise the instance using the built-in `visualise()` method to show the instance in isolation, with the remainder of the image blanked out.

# %%
building = buildings[0]
building.visualise()
# Out:
# (<Figure size 1600x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# We can also visualise a specific channel of the image. Here, we visualise the red channel, which corresponds to index `0`.

# %%
building.visualise(channel=0)
# Out:
# (<Figure size 1600x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# We can also extract a NumPy array representing the pixel values that correspond to the instance by using the built-in `masked()` method. This method also allows us to extract a specific channel. The result can then be used to compute statistics, such as `mean()`.

# %%
masked = building.masked()
masked_red = building.masked(channel=0)

# %% [markdown]
# For instance, we can easily compute the 'mean colour' of the instance...

# %%
masked_mean = masked.mean(axis = 0)
masked_mean
# Out:
# array([87.42520358, 84.4224337 , 79.8919507 ])

# %% [markdown]
# ...or the mean for a specific channel:

# %%
masked_red_mean = masked_red.mean(axis=0)
masked_red_mean
# Out:
# np.float64(87.42520358422257)

# %% [markdown]
# We can also perform the same operation on an HSV version of the image by passing `hsv=True` to the `masked()` method:

# %%
masked_hsv = building.masked(hsv=True)
masked_hsv
# Out:
# array([[0.77777778, 0.02097902, 0.56078431],
#        [0.95833333, 0.02816901, 0.55686275],
#        [0.03333333, 0.03333333, 0.58823529],
#        ...,
#        [0.61666667, 0.10752688, 0.36470588],
#        [0.59090909, 0.12087912, 0.35686275],
#        [0.625     , 0.13186813, 0.35686275]], shape=(210478, 3))

# %%
masked_v = building.masked(hsv=True, channel=2)
masked_v
# Out:
# array([0.56078431, 0.55686275, 0.58823529, ..., 0.36470588, 0.35686275,
#        0.35686275], shape=(210478,))

# %% [markdown]
# A built-in method is provided for convenience to extract the value (brightness) of the instance. It performs the same computation as the cell above.

# %%
brightness = building.brightness()
brightness.mean()
# Out:
# np.float64(0.35221362616445956)

# %% [markdown]
# ### Calculate statistics

# %%
# Compute albedo (mean V from HSV)
building_means = []
for seg in segmentations:
    buildings = seg.get_instances("building", exclude=["window", "door"], merge = True)
    building_means.append(buildings.brightness().mean())

# %%
building_means
# Out:
# [np.float64(0.3516668788247259),
#  np.float64(0.45730703491416486),
#  np.float64(0.46526121665594344),
#  np.float64(0.6087140380659822),
#  np.float64(0.21320057240186757)]

# %%
# TODO:
# instance.get_material()

# TODO:
# Add statistics to metadata

# TODO:
# Add model parameters to the segmentation metadata for each image (parquet file)
